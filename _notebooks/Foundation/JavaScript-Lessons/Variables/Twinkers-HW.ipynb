# %%
---
layout: base
toc: True
breadcrumb: True
title: JS Variables Homework
description: These are the homework problems and popcorn hacks.
permalink: /student/csse/javascript/fundamentals/variables-hw
author: Samarth H, Anish G, Krish K, Pranay K
---

# %% [markdown]
# <style>
# .glowing-text {
#   color: #fff;
#   text-shadow: 0 0 10px #8a2be2, 0 0 20px #8a2be2, 0 0 30px #4169e1, 0 0 40px #4169e1;
#   font-weight: bold;
#   margin-top: 0;
#   font-size: 2.5em;
#   text-align: center;
# }
#
# .section-header {
#   background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#   color: white;
#   padding: 20px;
#   border-radius: 15px;
#   margin: 20px 0;
#   text-align: center;
#   box-shadow: 0 8px 25px rgba(0,0,0,0.2);
#   font-weight: bold;
#   text-decoration: underline;
# }
#
# .instructions-box {
#   background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%);
#   color: white;
#   padding: 20px;
#   border-radius: 12px;
#   margin: 15px 0;
#   border-left: 5px solid #ff6b6b;
#   box-shadow: 0 4px 15px rgba(0,0,0,0.1);
# }
#
# .intro-banner {
#   background: linear-gradient(45deg, #8a2be2, #4169e1);
#   color: white;
#   padding: 30px;
#   border-radius: 20px;
#   text-align: center;
#   margin: 20px 0;
#   box-shadow: 0 10px 30px rgba(0,0,0,0.3);
# }
#
# .step-list {
#   background: rgba(255,255,255,0.1);
#   padding: 15px;
#   border-radius: 10px;
#   margin: 10px 0;
# }
#
# .step-list ol {
#   margin: 0;
#   padding-left: 20px;
# }
#
# .step-list li {
#   margin: 8px 0;
#   line-height: 1.6;
# }
#
# .homework-section {
#   background: linear-gradient(135deg, #ff9a9e 0%, #fecfef 50%, #fecfef 100%);
#   color: #333;
#   padding: 25px;
#   border-radius: 15px;
#   margin: 20px 0;
#   box-shadow: 0 6px 20px rgba(0,0,0,0.15);
# }
#
# .part-header {
#   background: linear-gradient(135deg, #ff6b6b 0%, #4ecdc4 100%);
#   color: white;
#   padding: 15px;
#   border-radius: 10px;
#   margin: 15px 0;
#   font-weight: bold;
#   text-align: center;
# }
# </style>
#
# <div class="intro-banner">
#   <h3 style="margin: 0 0 10px 0;">🎉 JavaScript Variables Learning Journey 🎉</h3>
#   <p style="margin: 0; font-size: 1.1em;">Presented by the</p>
#   <h4 class="glowing-text">TINKERERS</h4>
# </div>

# %% [markdown]
# <div class="section-header">
#   <h2 style="margin: 0;">🍿 Popcorn Hack 1 😈</h2>
#   <p style="margin: 10px 0 0 0; font-size: 1.1em;">Let's start diving into some interactive coding!</p>
# </div>
#
# <div class="instructions-box">
#   <h3 style="margin-top: 0;">📋 Instructions</h3>
#   <p>Below instructions refer to the interactive code cell that follows:</p>
#   <div class="step-list">
#     <ol>
#       <li>Adjust var declarations, names, values, etc. Mess around with it and observe any changes/errors.</li>
#       <li>Think and/or discuss with your table: what changes did you notice?</li>
#       <li>Uncomment the line saying <code>age = 2;</code> and look at your console. What do you notice?</li>
#       <li>Add a new variable called <code>hobby</code> with the value of "painting" and update the DOM output and console output to say: "[NAME] is [AGE] years old, lives in [CITY], and loves [HOBBY]"</li>
#       <li>There's a keyword called <code>typeof</code> in JavaScript. Use this keyword to also display the data types of the variables.</li>
#     </ol>
#   </div>
# </div>

# %%
# %%html
#
# <h2>Popcorn Hack 1 Output</h2>
# <div id="output1"></div>
#
# <script>
# (() => {
#
#   let name = "Precia";
#   const age = 14;
#
#   // In practice, you shouldn't use var. This is just for the purposes of teaching :)
#   var city = "San Diego";
#
#   // Change vars here
#   name = "preciaverma";
#   //age = 2;   // What happens if you uncomment this line ???
#   city = "Los Angeles";
#
#   document.getElementById("output1").innerText = name + " is " + age + " years old and lives in " + city + ".";
#   console.log(name + " is " + age + " years old and lives in " + city + ".")
#
# })();
# </script>

# %% [markdown]
# <div class="section-header">
#   <h2 style="margin: 0;">🍿 Popcorn Hack 2 😈</h2>
#   <p style="margin: 10px 0 0 0; font-size: 1.1em;">Magic Number Calculator</p>
# </div>
#
# <div class="instructions-box">
#   <h3 style="margin-top: 0;">📋 Instructions</h3>
#   <div class="step-list">
#     <ol>
#       <li>Go to the code cell below this text.</li>
#       <li>Using the correct JS variable naming convention, declare a Magic Number variable with the value returned by <code>input.value</code> to get a user response.</li>
#       <li>Convert it to a Number data type using <code>Number()</code>. Example: <code>let x = Number(x);</code> turns x into a Number. This is because prompt() always returns Strings.</li>
#       <li>Create variables <code>doubled</code>, <code>squared</code>, and <code>tripled</code> that contain the doubled, squared, and tripled values of the magic number.</li>
#       <li>Display the results in DOM and the console by changing <code>output.innerText</code> and using <code>console.log()</code>.</li>
#     </ol>
#   </div>
# </div>

# %%
# %%html
#
# <p>Click the button after entering your magic number!</p>
#
# <input type="number" id="magicInput" placeholder="input.value">
# <button id="magicButton">Calculate</button>
#
# <div id="output2">Your results will appear here.</div>
#
# <script>
#   (() => {
#
#   const button = document.getElementById("magicButton");
#   const input = document.getElementById("magicInput");
#   const output = document.getElementById("output2");
#
#   button.addEventListener("click", () => {
#
#     // ^^ DO NOT MODIFY ANY ABOVE CODE ^^
#
#     // Set the Magic Number variable to input.value
#     // _________________________________
#
#
#     // Convert the input to a number using Number()
#     // _________________________________
#
#     // Calculate doubled, squared, and half
#     // _________________________________
#     // _________________________________
#     // _________________________________
#
#     // Display results in the DOM and console
#     // output.innerText = ______;
#     // console.log(________);
#
#   // vv DO NOT MODIFY ANY BELOW CODE vv
#   });
#
#   })();
#
# </script>

# %% [markdown]
# <div class="section-header">
#   <h2 style="margin: 0;">📝 Variables Homework</h2>
#   <p style="margin: 10px 0 0 0; font-size: 1.1em;">Show what you know!</p>
# </div>
#
# <div class="homework-section">
#   <h3 style="text-align: center; color: #333; margin-bottom: 20px;">🎯 Understanding JavaScript Variables</h3>
#
#   <div class="part-header">
#     <h4 style="margin: 0;">Part A - Creating Variables</h4>
#   </div>
#
#   <ol>
#     <li><strong>Create a variable called <code>name</code></strong> and store your first name in it. Print it in the console and to DOM.</li>
#     <li><strong>Create two variables <code>age</code> and <code>city</code>.</strong> Print them in a single sentence like: "I am 15 years old and I live in New York."</li>
#     <li><strong>Create a variable <code>isStudent</code></strong> (true/false). Print it.</li>
#   </ol>
#
#   <div class="part-header">
#     <h4 style="margin: 0;">Part B - Numbers & Strings</h4>
#   </div>
#
#   <ol start="4">
#     <li><strong>Create two number variables</strong> num1 = 10 and num2 = 5. Print their sum, difference, product, and quotient.</li>
#     <li><strong>Make a variable <code>favoriteFood</code></strong> and print: "My favorite food is ____."</li>
#   </ol>
#
#   <div class="part-header">
#     <h4 style="margin: 0;">Part C - Practice Problems</h4>
#   </div>
#
#   <ol start="6">
#     <li><strong>Swap the values</strong> of two variables: x = 7 and y = 3.</li>
#     <li><strong>Create a variable <code>fullName</code></strong> by joining two strings: "FirstName" and "LastName".</li>
#     <li><strong>Convert temperature</strong> C = 25 into Fahrenheit using F = (C * 9/5) + 32.</li>
#     <li><strong>Create a variable score = 85.</strong> Print "Pass" if score >= 50, else "Fail".</li>
#     <li><strong>Write a program</strong> that asks for your name and age (use prompt) and prints: "Hello &lt;name&gt;, you are &lt;age&gt; years old."</li>
#     <li><strong>Creative Project!</strong> Make a project that uses 5 variables to run. It can do anything you want, have fun and good luck!</li>
#   </ol>
#
#   <div style="background: rgba(255,215,0,0.2); padding: 15px; border-radius: 8px; margin-top: 20px; border-left: 4px solid gold;">
#     <strong>💎 Extra Credit (Optional):</strong><br>
#     Instead of hard coding the variable for number 9 to 85, make the variable a random number from 1-100.
#   </div>
# </div>
#
# <div style="text-align: center; margin: 20px 0;">
#   <img src="https://as2.ftcdn.net/jpg/05/52/30/29/1000_F_552302940_Nct9zn3a6us0igBJqlkDQzQnbM4LLvmS.jpg" alt="Have Fun!" style="border-radius: 15px; box-shadow: 0 4px 15px rgba(0,0,0,0.2); max-width: 400px;">
# </div>

# %%
# %%html
#
# <h2>Homework Output</h2>
# <div id="output"></div>
#
# <script>
#   document.getElementById("output").innerText = ""; // Clear output
#   (() => {
#
#   // Part A - Creating Variables
#   // 1. Create a variable called name and store your first name in it
#   let name = "Precia";
#   console.log(name);
#   document.getElementById("output").innerText += "Name: " + name;
#
#   // 2. Create two variables age and city
#   const age = 14;
#   let city = "San Diego";
#   console.log("I am " + age + " years old and I live in " + city + ".");
#   document.getElementById("output").innerText += "\nI am " + age + " years old and I live in " + city + ".";
#
#   // 3. Create a variable isStudent
#   const isStudent = true;
#   console.log("Is student: " + isStudent);
#   document.getElementById("output").innerText += "\nIs student: " + isStudent;
#
#   // Part B - Numbers & Strings
#   // 4. Create two number variables and print operations
#   const num1 = 10;
#   const num2 = 5;
#
#   const sum = num1 + num2;
#   const difference = num1 - num2;
#   const product = num1 * num2;
#   const quotient = num1 / num2;
#
#   console.log("Numbers: " + num1 + " and " + num2);
#   console.log("Sum: " + sum);
#   console.log("Difference: " + difference);
#   console.log("Product: " + product);
#   console.log("Quotient: " + quotient);
#
#   document.getElementById("output").innerText += "\n\nNumbers: " + num1 + " and " + num2;
#   document.getElementById("output").innerText += "\nSum: " + sum;
#   document.getElementById("output").innerText += "\nDifference: " + difference;
#   document.getElementById("output").innerText += "\nProduct: " + product;
#   document.getElementById("output").innerText += "\nQuotient: " + quotient;
#
#   // 5. Create a favoriteFood variable
#   const favoriteFood = "pizza";
#   console.log("My favorite food is " + favoriteFood + ".");
#   document.getElementById("output").innerText += "\n\nMy favorite food is " + favoriteFood + ".";
#
#   // Part C - Practice Problems
#   document.getElementById("output").innerText += "\n\n--- Part C - Practice Problems ---";
#
#   // 6. Swap the values of two variables
#   let x = 7;
#   let y = 3;
#   console.log("Before swap: x = " + x + ", y = " + y);
#   document.getElementById("output").innerText += "\n\nBefore swap: x = " + x + ", y = " + y;
#
#   // Swapping using a temporary variable
#   let temp = x;
#   x = y;
#   y = temp;
#
#   console.log("After swap: x = " + x + ", y = " + y);
#   document.getElementById("output").innerText += "\nAfter swap: x = " + x + ", y = " + y;
#
#   // 7. Create a fullName variable by joining two strings
#   const firstName = "FirstName";
#   const lastName = "LastName";
#   const fullName = firstName + " " + lastName;
#
#   console.log("Full name: " + fullName);
#   document.getElementById("output").innerText += "\n\nFull name: " + fullName;
#
#   // 8. Convert temperature C = 25 into Fahrenheit
#   const celsius = 25;
#   const fahrenheit = (celsius * 9/5) + 32;
#
#   console.log(celsius + "°C = " + fahrenheit + "°F");
#   document.getElementById("output").innerText += "\n\n" + celsius + "°C = " + fahrenheit + "°F";
#
#   // 9. Create a variable score and print "Pass" or "Fail"
#   // For Extra Credit: Use random number from 1-100 instead of hardcoding 85
#   const score = Math.floor(Math.random() * 100) + 1; // Random number between 1-100
#   const result = score >= 50 ? "Pass" : "Fail";
#
#   console.log("Score: " + score + " - " + result);
#   document.getElementById("output").innerText += "\n\nScore: " + score + " - " + result;
#
#   // 10. Write a program that asks for name and age
#   document.getElementById("output").innerText += "\n\n--- User Input Simulation ---";
#   // Since we can't use actual prompt in a Jupyter Notebook cell, we'll simulate it:
#   const simulatedName = "Precia";
#   const simulatedAge = 14;
#
#   console.log("Hello " + simulatedName + ", you are " + simulatedAge + " years old.");
#   document.getElementById("output").innerText += "\nHello " + simulatedName + ", you are " + simulatedAge + " years old.";
#   document.getElementById("output").innerText += "\n(Note: This is simulated as prompt() doesn't work in notebooks)";
#
#   // 11. Creative Project
#   document.getElementById("output").innerText += "\n\n--- Creative Project: Simple Calculator ---";
#
#   // Using 5 variables to create a simple calculator
#   const num1Creative = 10;
#   const num2Creative = 5;
#   const operation = "multiply"; // could be add, subtract, multiply, divide
#   let resultCreative;
#   let message;
#
#   // Calculate based on operation
#   if (operation === "add") {
#     resultCreative = num1Creative + num2Creative;
#     message = num1Creative + " + " + num2Creative + " = " + resultCreative;
#   } else if (operation === "subtract") {
#     resultCreative = num1Creative - num2Creative;
#     message = num1Creative + " - " + num2Creative + " = " + resultCreative;
#   } else if (operation === "multiply") {
#     resultCreative = num1Creative * num2Creative;
#     message = num1Creative + " × " + num2Creative + " = " + resultCreative;
#   } else if (operation === "divide") {
#     resultCreative = num1Creative / num2Creative;
#     message = num1Creative + " ÷ " + num2Creative + " = " + resultCreative;
#   } else {
#     message = "Invalid operation";
#   }
#
#   console.log(message);
#   document.getElementById("output").innerText += "\n" + message;
#   document.getElementById("output").innerText += "\n\nCreative project uses 5 variables: num1Creative, num2Creative, operation, resultCreative, and message.";
#
#   })();
# </script>

# %% [markdown]
# <div class="section-header">
#   <h2 style="margin: 0;">📤 Submission</h2>
#   <p style="margin: 10px 0 0 0; font-size: 1.1em;">Submit your completed work!</p>
# </div>
#
# <div class="instructions-box">
#   <h3 style="margin-top: 0;">📋 How to Submit</h3>
#   <p>You will submit the link to your homework on a web page in the below form.</p>
#   <p>If you are unable to get your homework accessible from the website, you can upload this Jupyter notebook to the form.</p>
#
#   <div style="background: rgba(255,255,255,0.2); padding: 15px; border-radius: 8px; margin: 15px 0;">
#     <strong>⚠️ IMPORTANT:</strong> If uploading, please name this Jupyter notebook in this format:<br>
#     <code>[FirstName][LastName]_vars_hw.ipynb</code><br>
#     <em>Example: SamarthHande_hw.ipynb</em>
#   </div>
#
#   <div style="text-align: center; margin: 20px 0;">
#     <a href="https://forms.gle/UBDFErZpKpTApWap8" target="_blank" style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); color: white; padding: 15px 30px; border-radius: 25px; text-decoration: none; font-weight: bold; display: inline-block; box-shadow: 0 4px 15px rgba(0,0,0,0.2);">
#       🚀 SUBMIT HOMEWORK HERE
#     </a>
#   </div>
#
#   <h4>📊 Grading Requirements:</h4>
#   <ul>
#     <li><strong>0.3 points</strong> for each question completed (Parts A, B, and C)</li>
#     <li><strong>Up to 0.03 extra points</strong> for code that demonstrates exceptional creativity and comprehension</li>
#   </ul>
# </div>
