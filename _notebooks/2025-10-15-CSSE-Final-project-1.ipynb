# %%
---
layout: post
title: CSSE Final Project Links
description: Quick access links to CSSE Final Project resources
toc: true
comments: true
permalink: /final-project-links
author: Precia Verma
---

# %% [markdown]
# ## Project Resources
#
# <style>
# .button {
#   display: inline-block;
#   padding: 12px 24px;
#   margin: 10px;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: center;
#   text-decoration: none;
#   border-radius: 8px;
#   box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
#   transition: all 0.3s ease;
#   color: white !important; /* Added !important to ensure color is white */
#   min-width: 180px;
# }
#
# .button:hover {
#   transform: translateY(-3px);
#   box-shadow: 0 6px 8px rgba(0, 0, 0, 0.2);
#   opacity: 0.9;
#   color: white !important; /* Added to ensure hover state keeps text white */
# }
#
# /* Force text to be white for links */
# .container a {
#   color: white !important;
#   text-decoration: none !important;
# }
#
# .github { background: linear-gradient(135deg, #333333, #24292e); }
# .docs { background: linear-gradient(135deg, #2E8B57, #3CB371); } /* Changed green shade to sea green */
# .demo { background: linear-gradient(135deg, #4e54c8, #8f94fb); }
# .slides { background: linear-gradient(135deg, #f46b45, #eea849); }
# .video { background: linear-gradient(135deg, #e52d27, #b31217); }
# .data { background: linear-gradient(135deg, #834d9b, #d04ed6); }
#
# .container {
#   display: flex;
#   flex-wrap: wrap;
#   justify-content: center;
#   margin: 20px 0;
# }
#
# .section {
#   background-color: #f8f9fa;
#   border-radius: 10px;
#   padding: 20px;
#   margin: 20px 0;
#   box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);
# }
#
# /* Blue gradient background for the h2 */
# .title-bg {
#   background: linear-gradient(135deg, #0f2027, #203a43, #2c5364);
#   color: white !important;
#   padding: 20px;
#   text-align: center;
#   border-radius: 10px;
#   margin-bottom: 30px;
# }
#
# .title-bg h2 {
#   color: white !important;
#   margin: 0;
# }
#
# .title-bg p {
#   color: white !important;
#   margin: 5px 0 0 0;
# }
# </style>
#
# <h2 class="title-bg">CSSE Final Project (Resource Links)</h2>
#
# ### Ideation (Day 1-3)
#
# <div class="section">
#   <div class="container">
#     <a href="https://precia-verma.github.io/student/tdd" class="button github">TDD BLOG</a>
#     <a href="https://pages.opencodingsociety.com/plagiarism" class="button docs">Completed Teacher Example</a>
#     <a href="https://precia-verma.github.io/student/csse-final-project-demo" class="button demo">Random #3</a>
#   </div>
# </div>
#
# ### Project Resources
#
# <div class="section">
#   <div class="container">
#     <a href="https://docs.google.com/presentation/d/your-presentation-id" class="button slides">Random #4</a>
#     <a href="https://youtu.be/your-video-id" class="button video">Random #5</a>
#     <a href="https://docs.google.com/spreadsheets/d/your-data-id" class="button data">Random #6</a>
#   </div>
# </div>
#
# ### Additional Resources
#
# <div class="section">
#   <div class="container">
#     <a href="https://precia-verma.github.io/student/api-docs" class="button docs">Random #7</a>
#     <a href="https://precia-verma.github.io/student/technical-guide" class="button github">TRandom #8</a>
#     <a href="https://precia-verma.github.io/student/user-manual" class="button demo">Random #9</a>
#   </div>
# </div>
