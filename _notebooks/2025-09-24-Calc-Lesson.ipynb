# %%
---
title: Calculator Lesson
comments: true
layout: base
permalink: /calculator-lesson
description: Calculator Lesson
author: Me
---

# %% [markdown]
# # 🧮 Calculator Lesson
# > *Learn how to use **Booleans** and **Arrays** in a Calculator! Master the fundamentals of programming logic.*
#
# <div style="text-align: center; margin: 20px 0;">
#   <img src="https://media.giphy.com/media/3o7btPCcdNniyf0ArS/giphy.gif" alt="Calculator" width="300" style="border-radius: 10px;">
# </div>
#
# ---
# **Next Steps:**
# - 🏆 Complete coding challenges
# - 📈 Track your progress
# - 🤝 Join the coding community
# - 🎓 Earn certificates
# ---
#
# ## 📊 1️⃣ Arrays
# ### *What is an **ARRAY**?*
#
# Arrays are ordered collections of data that can store multiple values in a single variable. Think of them as containers that hold related information!
#
# **Key Features:**
# - 📦 Store multiple values
# - 🔢 Access elements by index
# - 📏 Dynamic size
# - 🔄 Iterable structure
#
# <div align="center" style="margin: 20px 0;">
#   <a href="https://www.khanacademy.org/math/arithmetic" target="_blank">
#     <button style="background: linear-gradient(135deg, #4ade80, #22c55e); color:white; padding:15px 30px; border:none; border-radius:12px; cursor:pointer; font-weight:bold; font-size:16px; box-shadow: 0 4px 15px rgba(74, 222, 128, 0.3); transition: all 0.3s ease;">
#       📚 Array Definition + Examples
#     </button>
#   </a>
#   <a href="https://www.calculatorsoup.com/" target="_blank" style="margin-left: 15px;">
#     <button style="background: linear-gradient(135deg, #34d399, #10b981); color:white; padding:15px 30px; border:none; border-radius:12px; cursor:pointer; font-weight:bold; font-size:16px; box-shadow: 0 4px 15px rgba(52, 211, 153, 0.3); transition: all 0.3s ease;">
#       🔧 Array Hack Challenge
#     </button>
#   </a>
# </div>
#
# ---
#
# ## 🔤 2️⃣ Booleans
# ### *What are **BOOLEANS**?*
#
# Booleans are the simplest data type - they can only be `true` or `false`. They're the foundation of all logical operations in programming!
#
# **Core Concepts:**
# - ✅ `true` - represents a positive condition
# - ❌ `false` - represents a negative condition
# - 🧠 Used in decision making
# - ⚡ Powers conditional statements
#
# <div align="center" style="margin: 20px 0;">
#   <a href="https://developer.mozilla.org/en-US/docs/Learn/JavaScript/First_steps" target="_blank">
#     <button style="background: linear-gradient(135deg, #60a5fa, #3b82f6); color:white; padding:15px 30px; border:none; border-radius:12px; cursor:pointer; font-weight:bold; font-size:16px; box-shadow: 0 4px 15px rgba(96, 165, 250, 0.3); transition: all 0.3s ease;">
#       🧠 Boolean Definition + Examples
#     </button>
#   </a>
#   <a href="https://www.w3schools.com/js/js_operators.asp" target="_blank" style="margin-left: 15px;">
#     <button style="background: linear-gradient(135deg, #3b82f6, #2563eb); color:white; padding:15px 30px; border:none; border-radius:12px; cursor:pointer; font-weight:bold; font-size:16px; box-shadow: 0 4px 15px rgba(59, 130, 246, 0.3); transition: all 0.3s ease;">
#       ⚡ Boolean Hack Challenge
#     </button>
#   </a>
# </div>
#
# ---
#
# ## 📝 3️⃣ Homework Assignments
# ### *Put Your Skills to the Test!*
#
# Ready to apply what you've learned? These hands-on exercises will help you master arrays and booleans in real calculator scenarios.
#
# **What You'll Build:**
# - 🎯 Array manipulation functions
# - 🔍 Boolean logic operations
# - 🧮 Calculator feature implementations
# - 🚀 Advanced programming concepts
#
# <div align="center" style="margin: 20px 0;">
#   <a href="https://codepen.io/pen" target="_blank">
#     <button style="background: linear-gradient(135deg, #facc15, #f59e0b); color:white; padding:15px 30px; border:none; border-radius:12px; cursor:pointer; font-weight:bold; font-size:16px; box-shadow: 0 4px 15px rgba(250, 204, 21, 0.3); transition: all 0.3s ease;">
#       🛠️ Start Your Homework Challenge!
#     </button>
#   </a>
# </div>
#
# ---
#
# ## 🌟 4️⃣ Practice & Level Up
# ### *Become a Programming Master!*
#
# Take your newfound knowledge to the next level with these advanced challenges and resources. The journey to coding mastery continues!
#
# <div align="center" style="margin: 20px 0;">
#   <a href="https://www.hackerrank.com/domains/tutorials/10-days-of-javascript" target="_blank">
#     <button style="background: linear-gradient(135deg, #f472b6, #ec4899); color:white; padding:15px 30px; border:none; border-radius:12px; cursor:pointer; font-weight:bold; font-size:16px; box-shadow: 0 4px 15px rgba(244, 114, 182, 0.3); transition: all 0.3s ease;">
#       🚀 Level Up on HackerRank
#     </button>
#   </a>
# </div>
#
# ---
#
# <div style="text-align: center; margin: 30px 0; padding: 20px; background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); border-radius: 15px; color: white;">
#   <h3 style="margin: 0; color: white;">🎉 Ready to Build Amazing Things?</h3>
#   <p style="margin: 10px 0; color: white;">You now have the tools to create powerful calculator features using arrays and booleans!</p>
# </div>
