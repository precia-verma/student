# %% [raw]
# ---
# layout: post
# title: Constellators - Conditionals HW
# description: These are the homework problems and popcorn hacks, created by Team Constellators.
# permalink: /conditionals-hw
# author: Precia Verma
# categories: [Homework]
# ---

# %% [markdown]
# ## **Conditionals**

# %% [markdown]
# ### <u>Popcorn Hack 1 - Simple Conditionals</u>
#
# Instructions:
# Finish the code in the cell below (fill in underlines and add lines of code) so it becomes a functioning conditional. What you make is up to you!
#
# **Examples of conditionals you could use:**
#
# 1) Define your mood today and give yourself ice cream if you're happy
# - challenge 1: add "else if" conditionals that echo different strings based on different moods
# - challenge 2: add user input to define a "mood" variable
#
# 2) Define the weather today and echo "It's sunny outside!" if it's sunny
# - challenge 1: add "else if" conditionals that define other weather
# - challenge 2: let the user input today’s weather and respond automatically
#
# 3) Define your age as a variable and check whether you are an adult or a child.
# - challenge 1: expand to add other categories using "else if" conditionals
# - challenge 2: create a random age generator and test the conditional multiple times to see different results
#
# The code is currently NOT functional. When you have completed this popcorn hack, the code should work. Have fun!

# %%
// Popcorn Hack 1 - Simple Conditionals

console.log("=== Popcorn Hack 1 - Simple Conditionals ===");

// Get user's mood
let mood = "happy"; // You can change this or make it random
console.log(`Your mood today: ${mood}`);

// Check mood and give appropriate treat
if (mood.toLowerCase() === "happy") {
    console.log("You're happy! You get ice cream 🍦");
} else if (mood.toLowerCase() === "sad") {
    console.log("Cheer up! Here's a cookie 🍪");
} else if (mood.toLowerCase() === "excited") {
    console.log("Awesome! You get a cupcake 🧁");
} else if (mood.toLowerCase() === "tired") {
    console.log("Rest up! You get some tea ☕");
} else {
    console.log("No mood specified!");
}

// Challenge: Test with different moods
const moods = ["happy", "sad", "excited", "tired"];
console.log("\nTesting different moods:");
moods.forEach(testMood => {
    console.log(`Mood: ${testMood}`);
    if (testMood === "happy") {
        console.log("  → You get ice cream! 🍦");
    } else if (testMood === "sad") {
        console.log("  → Here's a cookie! 🍪");
    } else if (testMood === "excited") {
        console.log("  → You get a cupcake! 🧁");
    } else if (testMood === "tired") {
        console.log("  → You get some tea! ☕");
    }
});
# Out:
#   Cell In[12], line 5
#     // Get user's mood
#                ^
# SyntaxError: unterminated string literal (detected at line 5)

# %% [markdown]
# ### <u>Popcorn Hack 2 - Vending Machine</u>
#
# Instructions:
# This hack is a bit more complicated than the first. Points will be awarded based on effort and completion.
#
# Analyze the block of code below. Then, complete the following instructions:
#
# You're hungry, so you go to your nearest vending machine for a snack. It makes you wonder if you'd be able to build your own. You can!... Digitally. Below, fill in the blanks so that when someone is prompted with food options, there are sub options within each food. (ex: Chocolate > Milk Chocolate)
#
# 1) **Create variables:**
# - snackChoice -> user input (prompt) to determine which random snack is chosen (number from 1-3)
#
# 2) **Add basic conditionals determining what type of snack was chosen**
#
# 3) **Add nested if statements for extra behavior**
#
# - Inside your chocolate condition:
#     - Add user input to determine what type of chocolate the user wants
# - Inside your candy condition:
#     - Add user input to determine what color candy the user wants
#
# 4) **Challenge (OPTIONAL):**
#
# - Make it so that there is a 10% chance of the vending machine giving you an extra cookie!

# %%
// Popcorn Hack 2 - Vending Machine

console.log("=== Popcorn Hack 2 - Vending Machine ===");

function vendingMachine(choice) {
    console.log(`You selected option ${choice}`);
    
    if (choice == "1") {
        // Chocolate bar option
        let chocolateType = "milk"; // You can change this to "dark" to test
        console.log("You got a chocolate bar!");
        
        if (chocolateType.toLowerCase() === "milk") {
            console.log("Enjoy your creamy milk chocolate bar! 🍫");
        } else if (chocolateType.toLowerCase() === "dark") {
            console.log("Savor your rich dark chocolate bar! 🍫");
        } else {
            console.log("Unknown chocolate type!");
        }
        
    } else if (choice == "2") {
        // Chips option
        console.log("You got a bag of chips! 🥔");
        
    } else if (choice == "3") {
        // Candy option
        let candyColor = "red"; // You can change this to "green" or "yellow" to test
        console.log("You got candy!");
        
        if (candyColor.toLowerCase() === "red") {
            console.log("Sweet! You got red strawberry candy! 🍓");
        } else if (candyColor.toLowerCase() === "green") {
            console.log("Tasty! You got green apple candy! 🍏");
        } else if (candyColor.toLowerCase() === "yellow") {
            console.log("Yummy! You got yellow lemon candy! 🍋");
        } else {
            console.log("Mystery flavor candy - surprise! 🍬");
        }
        
    } else {
        console.log("Invalid choice! Please choose 1, 2, or 3 next time.");
    }
    
    // Challenge: 10% chance of extra cookie
    if (Math.random() < 0.1) {
        console.log("🎉 Bonus treat! The machine gives you an extra cookie! 🍪");
    }
}

// Test all options
console.log("Testing all vending machine options:\n");
vendingMachine("1");
console.log("");
vendingMachine("2");
console.log("");
vendingMachine("3");
console.log("");
vendingMachine("4"); // Invalid choice
# Out:
#   Cell In[8], line 1
#     // Popcorn Hack 2 - Vending Machine
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### <u>Homework</u>
#
# Complete the following questions in the next code block.
#
# 1) Create a variable called "temperature" that defines a temperature. If it's above 80 degrees, print "It’s hot outside!". Otherwise, print "It’s nice outside."
#
# 2) Create a variable called "score". If score >= 90 print "A", 80-89 print "B", 70-79 print "C", otherwise print "Needs improvement."
#
# 3) Add a function to your "score" variable that prompts the user to input their score.
#
# 4) Define a variable "number". If it’s even, print "Even Number"; otherwise, print "Odd number."
#
# 5) Instead of defining the variable "number," make the number a random integer from 1-10.
#
# 6) Define a variable called "day" (like 'Monday', 'Tuesday', etc.) and use a switch statement to print a message for that day.
#
# 7) Add statements to the previous conditional: If today is 'Saturday' or 'Sunday', print "Weekend!"; else print "Weekday!".
#
# 8) Create a boolean called "loggedIn" (true or false). If true, print "Welcome back!", otherwise print "Please log in."
#
# 9) Define a variable "weather". If it's raining, print "It's raining." Else, print "Go outside, it's a nice day today!"
#
# 10) **Extra Credit:** Submit the original OOP Breakout Game Code (found on [OpenCS](https://github.com/Open-Coding-Society/pages/blob/main/hacks/breakout/breakout.md?plain=1)) after making the following edits:
# - Add a conditional to the game that changes the color of the ball every time it hits the wall or another brick.
# - Try making the ball do something different when it collides (ex: speed up, shrink, glow).
# - Make sure your code is functional before you submit!
# - Have fun!

# %%
// Conditionals Homework - Interactive Version

console.log("=== Welcome to Conditionals Homework ===");
console.log("This homework will ask you questions and test your conditional logic!");

// 1) Temperature check
console.log("\n1) Temperature Check:");
let temperature = prompt("What's the temperature outside today? (enter a number)");
temperature = parseFloat(temperature);
if (temperature > 80) {
    console.log(`Temperature is ${temperature}°F - It's hot outside!`);
} else {
    console.log(`Temperature is ${temperature}°F - It's nice outside!`);
}

// 2) Grade calculator  
console.log("\n2) Grade Calculator:");
let score = prompt("What score did you get on your test? (0-100)");
score = parseFloat(score);
let grade;
if (score >= 90) {
    grade = "A";
} else if (score >= 80) {
    grade = "B";
} else if (score >= 70) {
    grade = "C";
} else {
    grade = "Needs improvement";
}
console.log(`Your score of ${score} = Grade: ${grade}`);

// 3) Grade function demonstration
console.log("\n3) Grade Function Demo:");
function calculateGrade(userScore) {
    let userGrade;
    if (userScore >= 90) {
        userGrade = "A - Excellent!";
    } else if (userScore >= 80) {
        userGrade = "B - Good job!";
    } else if (userScore >= 70) {
        userGrade = "C - Keep it up!";
    } else {
        userGrade = "Keep practicing!";
    }
    return userGrade;
}
let anotherScore = prompt("Enter another test score to see the grade function in action:");
anotherScore = parseFloat(anotherScore);
console.log(`Function result for ${anotherScore}: ${calculateGrade(anotherScore)}`);

// 4) Even or odd number
console.log("\n4) Even/Odd Check:");
let number = prompt("Enter any number to check if it's even or odd:");
number = parseInt(number);
if (number % 2 === 0) {
    console.log(`${number} is an even number`);
} else {
    console.log(`${number} is an odd number`);
}

// 5) Random number comparison
console.log("\n5) Random Number Game:");
let randomNum = Math.floor(Math.random() * 10) + 1;
let guess = prompt(`I'm thinking of a number from 1-10. Can you guess it? The number is ${randomNum}. Enter your guess:`);
guess = parseInt(guess);
if (guess === randomNum) {
    console.log(`🎉 Amazing! You guessed ${randomNum} correctly!`);
} else {
    console.log(`Nice try! You guessed ${guess}, but I was thinking of ${randomNum}`);
}
let isEven = (randomNum % 2 === 0);
console.log(`The number ${randomNum} is ${isEven ? 'even' : 'odd'}`);

// 6) Day of the week with switch
console.log("\n6) Day of the Week:");
let day = prompt("What day of the week is it today? (e.g., Monday, Tuesday, etc.)");
let dayMessage;
switch (day) {
    case "Monday":
        dayMessage = "Fresh start!";
        break;
    case "Tuesday":
        dayMessage = "Getting momentum!";
        break;
    case "Wednesday":
        dayMessage = "Hump day - you got this!";
        break;
    case "Thursday":
        dayMessage = "Almost Friday!";
        break;
    case "Friday":
        dayMessage = "TGIF - Weekend's here!";
        break;
    case "Saturday":
        dayMessage = "Saturday vibes!";
        break;
    case "Sunday":
        dayMessage = "Sunday funday!";
        break;
    default:
        dayMessage = "Hmm, that doesn't seem like a valid day!";
}
console.log(`${day}: ${dayMessage}`);

// 7) Weekend check
console.log("\n7) Weekend Check:");
let isWeekend = (day === "Saturday" || day === "Sunday");
console.log(`${day} is a ${isWeekend ? 'Weekend! 🎉' : 'Weekday! 💼'}`);

// 8) Login status
console.log("\n8) Login Status:");
let loginResponse = prompt("Are you logged in? (yes/no)");
let loggedIn = (loginResponse.toLowerCase() === "yes" || loginResponse.toLowerCase() === "y");
if (loggedIn) {
    console.log("Welcome back, friend! 👋");
} else {
    console.log("Please log in to continue 🔐");
}

// 9) Weather report
console.log("\n9) Weather Report:");
let weather = prompt("How's the weather today? (sunny, rainy, cloudy, etc.)");
if (weather.toLowerCase().includes("rain")) {
    console.log("It's raining - grab an umbrella! ☔");
} else if (weather.toLowerCase().includes("sunny")) {
    console.log("Sunny day - perfect for going outside! ☀️");
} else {
    console.log(`${weather} weather - sounds nice! 🌤️`);
}

console.log("\n🎓 Homework Complete! Great job working through all the conditionals!");
# Out:
#   Cell In[11], line 5
#     // 1) Temperature check
#         ^
# SyntaxError: unmatched ')'
